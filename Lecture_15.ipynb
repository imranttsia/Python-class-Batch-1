# %%
x="hotmail"

# %%
y=x[3]

# %%
print(y)
# Out:
# m

# %%
print(len(x))
# Out:
# 7

# %%
print(len("hotmail"))
# Out:
# 7

# %%
a = len(x) - 1

# %%
last = x[a]
print(last)
# Out:
# l

# %%
r=x[-1]
print(r)
# Out:
# l

# %%
for item in x:
  print(item)
# Out:
# h
# o
# t
# m
# a
# i
# l

# %%
for item in x:
  print(item, end="")
# Out:
# hotmail

# %%
s="Python"
n=len(s)
i=0
print("forward dir")
while i<n:
  print(s[i])
  i+=1
print()
print("Reverse dir")
print()
i=-1
while i>=-n:
  print(s[i])
  i-=1
# Out:
# forward dir
# P
# y
# t
# h
# o
# n
#
# Reverse dir
#
# n
# o
# h
# t
# y
# P

# %%
s="python"
print("n" in s)
# Out:
# True

# %%
s="python"
print("a" in s)
# Out:
# False

# %%
s="python"
print("n" not in s)
# Out:
# False

# %%
s="python"
print("a" not in s)
# Out:
# True

# %%
s=input("Enter main string:  ")
subs=input("Enter substring:  ")
if subs in s:
    print(subs,"is found in main string")
else:
    print(subs,"is not found in main string")
# Out:
# Enter main string:  My name is ali
# Enter substring:  ali
# ali is found in main string

# %%
s=input("Enter main string:  ")
subs=input("Enter substring:  ")
if subs in s:
    print(subs,"is found in main string")
else:
    print(subs,"is not found in main string")
# Out:
# Enter main string:  My name is ali
# Enter substring:  Ahmed
# Ahmed is not found in main string

# %% [markdown]
# #slicing
#
# S[A:B-1]

# %%
s="Python Course"
print(s[0:6])
# Out:
# Python

# %%
s="Python Course"
print(s[7:13])
# Out:
# Course

# %%
s="Python Course"
print(s[:13])
# Out:
# Python Course

# %%
s="Python Course"
print(s[3:])
# Out:
# hon Course

# %%
s="Python Course"
print(s[3:3])

# %%
s="Python Course"
print(s[1:13:4])
# Out:
# ynu

# %%
s="Python Course"
print(s[-1:])
# Out:
# e

# %%
s="Python Course"
print(s[:-2])
# Out:
# Python Cour

# %%
s="Python Course"
print(s[::-2])
# Out:
# ero otP

# %%
s="Python Course"
print(s[::-1])
# Out:
# esruoC nohtyP

# %% [markdown]
# Strings are immutable

# %%
s="Python Course"
s[0]="J"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2006023012.py in <cell line: 0>()
#       1 s="Python Course"
# ----> 2 s[0]="J"
#
# TypeError: 'str' object does not support item assignment

# %%
s="Python Course"
s_new="J"+s[1:]
print(s_new)
# Out:
# Jython Course

# %%
"new"+"year"
# Out:
# 'newyear'

# %%
a=12445566
print(a[2:4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1755486721.py in <cell line: 0>()
#       1 a=12445566
# ----> 2 print(a[2:4])
#
# TypeError: 'int' object is not subscriptable

# %%
s1=input("Enter first string:  ")
s2=input("Enter second string: ")
if s1==s2:
  print("Both strings are equal")
elif s1<s2:
  print("First string is less than second string")
else:
  print("First string is greater than second string")
# Out:
# Enter first string:  Ali
# Enter second string: Ahmed
# First string is greater than second string

# %%
s1=input("Enter first string:  ")
s2=input("Enter second string: ")
if s1==s2:
  print("Both strings are equal")
elif s1<s2:
  print("First string is less than second string")
else:
  print("First string is greater than second string")
# Out:
# Enter first string:  Ali
# Enter second string: Ali
# Both strings are equal

# %%
s1=input("Enter first string:  ")
s2=input("Enter second string: ")
if s1==s2:
  print("Both strings are equal")
elif s1<s2:
  print("First string is less than second string")
else:
  print("First string is greater than second string")
# Out:
# Enter first string:  Ahmed
# Enter second string: Ali
# First string is less than second string

# %% [markdown]
# object.function(arguments)

# %%
dir

# %%
sample_string = "hello world"
print(dir(sample_string))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
# To get more details about a specific method, for example, the 'upper' method:
help(str.upper)
# Out:
# Help on method_descriptor:
#
# upper(self, /) unbound builtins.str method
#     Return a copy of the string converted to uppercase.

# %%
word="banana"
new_word=word.upper()
print(new_word)
# Out:
# BANANA

# %%
word="banana"
new_word=word.upper("ana")
print(new_word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-825949107.py in <cell line: 0>()
#       1 word="banana"
# ----> 2 new_word=word.upper("ana")
#       3 print(new_word)
#
# TypeError: str.upper() takes no arguments (1 given)

# %%
word="banana"
index=word.find("a")
print(index)
# Out:
# 1

# %%
word="banana"
index=word.find("na")
print(index)
# Out:
# 2

# %%
word="banana"
index=word.find("a",4)
print(index)
# Out:
# 5

# %%
line="   Python Course   "
result=line.strip()
print(line)
print(result)
# Out:
#    Python Course
# Python Course

# %%
line="Have a nice day"
line.startswith("Have")
# Out:
# True

# %%
line="Have a nice day"
line.startswith("day")
# Out:
# False

# %%
line="Have a nice day"
line.startswith("have")
# Out:
# False

# %%
x="Python course"
x.replace("Python","Java")
# Out:
# 'Java course'

# %%
x="Python course"
x.replace("Jave","Python")
# Out:
# 'Python course'

# %%
x="Python course"
x.replace("Jave")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3197036706.py in <cell line: 0>()
#       1 x="Python course"
# ----> 2 x.replace("Jave")
#
# TypeError: replace expected at least 2 arguments, got 1

# %%
x="Python course"
x.replace("Jave","Python")

# %%
x="Python Python Python course"
x.replace("Python","Java", 2)
# Out:
# 'Java Java Python course'
