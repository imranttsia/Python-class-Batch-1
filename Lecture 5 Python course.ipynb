# %%
F=float(input("Temperature in Farenheit"))
C=(F-32)*(5/9)

print(f"The temperature in centigrade will be {C:.2f} Celsius")
# Out:
# Temperature in Farenheit67
# The temperature in centigrade will be 19.44 Celsius

# %% [markdown]
# If a five-digit number is input through the keyboard, write a program to calculate the sum of its digit.

# %%
num=int(input("Enter five digit number"))
sum=0
a=num%10
num=num//10
sum=sum+a
a=num%10
num=num//10
sum=sum+a
a=num%10
num=num//10
sum=sum+a
a=num%10
num=num//10
sum=sum+a
a=num%10
sum=sum+a
print("sum of 5 digits=",sum)
# Out:
# Enter five digit number54321
# sum of 5 digits= 15

# %%
53421//10
# Out:
# 5342

# %%
54321/10
# Out:
# 5432.1

# %%
5==5
# Out:
# True

# %%
5==6
# Out:
# False

# %%
5=5
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_8764\2359669884.py", line 1
#     5=5
#     ^
# SyntaxError: cannot assign to literal

# %%
x=5

# %%
x==5
# Out:
# True

# %%
x==6
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(1)
# Out:
# int

# %%
type("rt")
# Out:
# str

# %%
type(False)
# Out:
# bool

# %% [markdown]
# x!=y (x is not equal to y)
# x>y (x is greater than y)
# x<y (x is lesser than y)
# x>=y (x is greater and equal to y)
# x<=y (x is less and equal to y)
# x is y (x is same as y)
# x is not y (x is not same as y)

# %%
x==7
# Out:
# False

# %%
x!=7
# Out:
# True

# %%
x>5
# Out:
# False

# %%
x<6
# Out:
# True

# %%
x>=4
# Out:
# True

# %%
x<=8
# Out:
# True

# %%
y=4

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True

# %%
(2**2)**2==2**(2**2)
# Out:
# True

# %%
(3**3)**3==3**(3**3) #19683==7.6255975e+12
# Out:
# False

# %%
"cat"<"mat"
# Out:
# True

# %%
"Cat"<"cat"
# Out:
# True

# %%
"Cat">"cat"
# Out:
# False

# %%
"Cat"=="cat"
# Out:
# False

# %%
"cat"<"catod"
# Out:
# True

# %%
"mat"<"catod"
# Out:
# False

# %% [markdown]
# Logical Operator (and | or)

# %%
2>4 and 6<7
# Out:
# False

# %%
2>4 or 6<7
# Out:
# True

# %%
2>4 or 6<7 and 4>5
# Out:
# False

# %%
3<4
# Out:
# True

# %%
not 3<4
# Out:
# False

# %% [markdown]
# # If Statement

# %% [markdown]
# Check if a number is positive

# %%
num=-4
if num>0:
    print("The number is positive")

# %%
num=int(input("Enter Value:"))
if num>0:
    print("The number is positive")
# Out:
# Enter Value:0

# %% [markdown]
# Assign a grade based on a score

# %%
Student=(input("Enter Student Name:"))
M=int(input("Enter Marks of Mathematics:"))
P=int(input("Enter Marks of Physics:"))
C=int(input("Enter Marks of Chemistry:"))
Per=(M+P+C)/3
if Per>=90:
    grade="A"
if Per>=80 and Per<90:
    grade="B"
if Per>=70 and Per<80:
    grade="C"
if Per>=60 and Per<70:
    grade="D"
if Per>=50 and Per<60:
    grade="E"
if Per<50:
    grade="Fail" 
    
print(f"{Student} get percentage {Per: .2f} % and grade {grade}.")
# Out:
# Enter Student Name:ali
# Enter Marks of Mathematics:76
# Enter Marks of Physics:76
# Enter Marks of Chemistry:78
# ali get percentage  76.67 % and grade C.

# %% [markdown]
# Status check based on temperature

# %%
Temp=float(input("Temperature in Centigrade:"))
if Temp>=40:
    print("Danger - Heat Stroke Risk")
if Temp>30 and Temp<40:
    print("Temperature is High")
if Temp<=30:
    print("Temperature is Moderate and no risk")
# Out:
# Temperature in Centigrade:25
# Temperature is Noderate and no risk
