# %% [markdown]
# Exponent: 5 raise to the power 2

# %%
5**2
# Out:
# 25

# %%
x=5**2

# %%
print(x)
# Out:
# 25

# %% [markdown]
# PEMDAS

# %%
3+6/2
# Out:
# 6.0

# %%
(3+6)/2
# Out:
# 4.5

# %%
4+4*3/2-3**3
# Out:
# -17.0

# %% [markdown]
# 4+4*3/2-3**3
# 4+12/2-27
# 4+6-27
# -17

# %%
(4+4)*(3/2)-3**3
# Out:
# -15.0

# %% [markdown]
# 8*1.5-27
# 12-17
# -15

# %% [markdown]
# Relational OR Comparison Operators
# a>b
# a<b
# a==b
# a>=b
# a<=b

# %%
4>3
# Out:
# True

# %%
5>8
# Out:
# False

# %%
x=5

# %%
x==5
# Out:
# True

# %%
x==4
# Out:
# False

# %%
x>=6
# Out:
# False

# %%
x<=6
# Out:
# True

# %%
x>=5
# Out:
# True

# %%
x<=5
# Out:
# True

# %% [markdown]
# String Operator

# %%
x=6
y=7

# %%
x+y
# Out:
# 13

# %%
x="6"
y="7"

# %%
x+y
# Out:
# '67'

# %%
x=6
y="7"

# %%
x*y
# Out:
# '777777'

# %%
x+y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6948\1525011898.py in <module>
# ----> 1 x+y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a="I have computer"

# %%
a="I have "computer""
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_6948\2463472741.py", line 1
#     a="I have "computer""
#                ^
# SyntaxError: invalid syntax

# %%
a="I have 'computer'"

# %%
print(a)
# Out:
# I have 'computer'

# %%
a='I have "computer"'

# %%
print(a)
# Out:
# I have "computer"

# %%
a="I have \"computer\""

# %%
print(a)
# Out:
# I have "computer"

# %%
a="I have computer
I use it regularly"
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_6948\1978130012.py", line 1
#     a="I have computer
#                       ^
# SyntaxError: EOL while scanning string literal

# %%
a="I have computer\
I use it regularly"

# %%
print(a)
# Out:
# I have computerI use it regularly

# %%
a="""A computer is an electronic device that processes data and performs tasks based on a set of instructions, or software. Invented in concept by Charles Babbage, the "father of the computer," this technology has evolved from room-sized machines to the portable laptops and smartphones we use today, becoming an essential part of modern life.
Modern computers consist of both hardware (physical components) and software (programs and data). Key hardware parts include the Central Processing Unit (CPU), often called the "brain" of the computer, memory (RAM for temporary data and storage for permanent files), and input/output devices like keyboards, mice, and monitor"""

# %%
print(a)
# Out:
# A computer is an electronic device that processes data and performs tasks based on a set of instructions, or software. Invented in concept by Charles Babbage, the "father of the computer," this technology has evolved from room-sized machines to the portable laptops and smartphones we use today, becoming an essential part of modern life.
# Modern computers consist of both hardware (physical components) and software (programs and data). Key hardware parts include the Central Processing Unit (CPU), often called the "brain" of the computer, memory (RAM for temporary data and storage for permanent files), and input/output devices like keyboards, mice, and monitor

# %%
print("ABC")
# Out:
# ABC

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A\nB\nC")
# Out:
# A
# B
# C

# %%
print("A\nBC")
# Out:
# A
# BC

# %%
print("A\tB\tC")
# Out:
# A	B	C

# %%
print("AFT\bBC")
# Out:
# BC

# %%
print("A\aB\aC")
# Out:
# ABC

# %% [markdown]
# INPUT

# %%
a=3

# %%
print(a)
# Out:
# 3

# %%
a=input()
# Out:
# 6

# %%
print(a)
# Out:
# 6

# %%
type(a)
# Out:
# str

# %%
a=int(input())
# Out:
# 6

# %%
print(a)
# Out:
# 6

# %%
type(a)
# Out:
# int

# %%
a=(float(input()))
# Out:
# 8

# %%
print(a)
# Out:
# 8.0

# %%
type(a)
# Out:
# float

# %%
a=input()
# Out:
# hello

# %%
print(a)
# Out:
# hello

# %%
a=int(input())
# Out:
# hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6948\2310251140.py in <module>
# ----> 1 a=int(input())
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
a=float(input())
# Out:
# hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6948\547461196.py in <module>
# ----> 1 a=float(input())
#
# ValueError: could not convert string to float: 'hello'

# %%
x=input("What is your name=")
# Out:
# What is your name=Imran

# %%
print(x)
# Out:
# Imran

# %%
type(x)
# Out:
# str

# %%
x=int(input("What is your age="))
# Out:
# What is your age=34

# %%
print(x)
# Out:
# 34

# %%
type(x)
# Out:
# int

# %%
print("Please enter an integer value:")
x=input()
print("Please enter second integer value:")
y=input()
num1=int(x)
num2=int(y)
z=num1+num2
print(z)
# Out:
# Please enter an integer value:
# 4
# Please enter second integer value:
# 5
# 9

# %%
x=input("Please enter an integer value:")
y=input("Please enter second integer value:")
num1=int(x)
num2=int(y)
z=num1+num2
print(z)
# Out:
# Please enter an integer value:4
# Please enter second integer value:5
# 9

# %%
x=int(input("Please enter an integer value:"))
y=int(input("Please enter second integer value:"))

z=x+y
print(z)
# Out:
# Please enter an integer value:4
# Please enter second integer value:5
# 9

# %%
x=int(input("Please enter an integer value:"))
y=int(input("Please enter second integer value:"))

z=x+y
print("The result is",z)
# Out:
# Please enter an integer value:4
# Please enter second integer value:5
# The result is 9

# %%
x=int(input("Please enter an integer value:"))
y=int(input("Please enter second integer value:"))

z=x+y
print("The result of",x,"and",y, "is",z)
# Out:
# Please enter an integer value:4
# Please enter second integer value:5
# The result of 4 and 5 is 9

# %%
x=int(input("Please enter an integer value:"))
y=int(input("Please enter second integer value:"))

print("The result of",x,"and",y, "is",x+y)
# Out:
# Please enter an integer value:4
# Please enter second integer value:5
# The result of 4 and 5 is 9

# %%
name = "Alice"
age = 25
print("%s is %d years old." % (name, age))
# Out:
# Alice is 25 years old.

# %%
name = "Alice"
age = 25
print("%d is %s years old." % (age, name))
# Out:
# 25 is Alice years old.

# %%
price = 19.99
print("The price is $%.2f." % price)
# Out:
# The price is $19.99.

# %%
price = 19.99
print("The price is $%.1f." % price)
# Out:
# The price is $20.0.

# %%
price = 19.99
print("The price is $%.3f." % price)
# Out:
# The price is $19.990.

# %%
name = "Bob"
age = 30
print("{} is {} years old.".format(name, age))
# Out:
# Bob is 30 years old.

# %%
product = "Python Course"
price = 99.99
print("{name} costs ${price:.2f}.".format(name=product, price=price))
# Out:
# Python Course costs $99.99.

# %%
x=int(input("Please enter an integer value:"))
y=int(input("Please enter second integer value:"))

print("The result of",x,"and",y, "is",x+y)
# Out:
# Please enter an integer value:4.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6948\3853089989.py in <module>
# ----> 1 x=int(input("Please enter an integer value:"))
#       2 y=int(input("Please enter second integer value:"))
#       3
#       4 print("The result of",x,"and",y, "is",x+y)
#
# ValueError: invalid literal for int() with base 10: '4.5'

# %%
x=int(input("Please enter an integer value:"))
y=int(input("Please enter second integer value:"))

print("The result of",x,"and",y, "is",x+y)
# Out:
# Please enter an integer value:hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6948\3853089989.py in <module>
# ----> 1 x=int(input("Please enter an integer value:"))
#       2 y=int(input("Please enter second integer value:"))
#       3
#       4 print("The result of",x,"and",y, "is",x+y)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
x=float(input("Please enter an integer value:"))
y=float(input("Please enter second integer value:"))

print("The result of",x,"and",y, "is",x+y)
# Out:
# Please enter an integer value:4.5
# Please enter second integer value:5.6
# The result of 4.5 and 5.6 is 10.1

# %%
x=float(input("Please enter an integer value:"))
y=float(input("Please enter second integer value:"))

print("The result of",x,"and",y, "is",x+y)
# Out:
# Please enter an integer value:4
# Please enter second integer value:5
# The result of 4.0 and 5.0 is 9.0

# %%
x=int(float(input("Please enter an integer value:")))
y=int(float(input("Please enter second integer value:")))

print("The result of",x,"and",y, "is",x+y)
# Out:
# Please enter an integer value:4.5
# Please enter second integer value:5.5
# The result of 4 and 5 is 9

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A",end='')
print("B",end='')
print("C",end='')
# Out:
# ABC

# %%
print("A",end='.')
print("B",end='.')
print("C",end='.')
# Out:
# A.B.C.

# %%
print("A",end='\n')
print("B",end='\n')
print("C",end='\n')
# Out:
# A
# B
# C

# %%
print("A",end='\t')
print("B",end='\t')
print("C",end='\t')
# Out:
# A	B	C

# %%
w,x,y,z=10,15,20,25
print(w,x,y,z)
# Out:
# 10 15 20 25

# %%
w,x,y,z=10,15,20,25
print(w,x,y,z, sep=',')
# Out:
# 10,15,20,25

# %%
w,x,y,z=10,15,20,25
print(w,x,y,z, sep='')
# Out:
# 10152025

# %%
w,x,y,z=10,15,20,25
print(w,x,y,z, sep=':')
# Out:
# 10:15:20:25

# %%
w,x,y,z=10,15,20,25
print(w,x,y,z, sep='--------')
# Out:
# 10--------15--------20--------25

# %%
#print details of first number
print("Please enter an integer value:")
#Inputting the first number
x=input()
#print details of second number
print("Please enter second integer value:")
#Inputting the first number
y=input()
#Convering first number from string to integer
num1=int(x)
#Convering second number from string to integer
num2=int(y)
#Additing two numbers
z=num1+num2
#printing result
print(z)
# Out:
# Please enter an integer value:
# 5
# Please enter second integer value:
# 6
# 11

# %%
print("Please enter an integer value:")   #print details of first number
x=input()   #Inputting the first number
print("Please enter second integer value:")    #print details of second number
y=input()    #Inputting the first number
num1=int(x)    #Convering first number from string to integer
num2=int(y)     #Convering second number from string to integer
z=num1+num2    #Additing two numbers
print(z)    #printing result
# Out:
# Please enter an integer value:
# 4
# Please enter second integer value:
# 5
# 9
