# %%
2=x
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_1980\3727837188.py", line 1
#     2=x
#     ^
# SyntaxError: cannot assign to literal

# %%
z=x+y
x=2
y=3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1980\3846223439.py in <module>
# ----> 1 z=x+y
#       2 x=2
#       3 y=3
#
# NameError: name 'x' is not defined

# %% [markdown]
# Addition of two number

# %%
x=2
y=3
z=x-y
print(z)
# Out:
# -1

# %% [markdown]
# # Value, expression and statement

# %% [markdown]
# # Value

# %% [markdown]
# String (Text and number), Integer(Whole number), Float(Decimal/Fraction)

# %%
Syed imran ali
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_1980\55015675.py", line 1
#     Syed imran ali
#          ^
# SyntaxError: invalid syntax

# %%
"""Syed Imran Ali"""
# Out:
# 'Syed Imran Ali'

# %%
"1"
# Out:
# '1'

# %%
"1"+"2"
# Out:
# '12'

# %%
type("Syed Imran Ali")
# Out:
# str

# %%
1
# Out:
# 1

# %%
type(1)
# Out:
# int

# %%
type(syed imran ali)
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_1980\1242883040.py", line 1
#     type(syed imran ali)
#               ^
# SyntaxError: invalid syntax

# %%
2.3
# Out:
# 2.3

# %%
type(2.3)
# Out:
# float

# %%
type(1.0)
# Out:
# float

# %%
type(-1)
# Out:
# int

# %%
print(type(-1))
# Out:
# <class 'int'>

# %%
print(type("syed"))
# Out:
# <class 'str'>

# %%
bool(12>4)
# Out:
# True

# %%
bool(12>41)
# Out:
# False

# %%
print(1,000,00)
# Out:
# 1 0 0

# %% [markdown]
# # Variable

# %%
x="imran"
print(x)
# Out:
# imran

# %%
y=1
print(y)
# Out:
# 1

# %%
z=4.5
print(z)
# Out:
# 4.5

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# int

# %%
type(z)
# Out:
# float

# %%
x+y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1980\1525011898.py in <module>
# ----> 1 x+y
#
# TypeError: can only concatenate str (not "int") to str

# %%
y+z
# Out:
# 5.5

# %%
x,y,z="imran ali",2,5

# %%
print(x)
# Out:
# imran ali

# %%
print(y)
# Out:
# 2

# %%
print(z)
# Out:
# 5

# %%
id(x)
# Out:
# 2555886961840

# %%
id(y)
# Out:
# 2555803429200

# %%
id(z)
# Out:
# 2555803429296

# %%
x=y=z=6

# %%
id(x)
# Out:
# 2555803429328

# %%
id(y)
# Out:
# 2555803429328

# %%
id(z)
# Out:
# 2555803429328

# %% [markdown]
# complex number = a+bj a=real part, bj= imaginary part

# %%
a=2+4j

# %%
b=5-3j

# %%
c=a+b
print(c)
# Out:
# (7+1j)

# %%
print(a.real)
# Out:
# 2.0

# %%
type(a)
# Out:
# complex

# %%
type(b)
# Out:
# complex

# %%
print(a.imag)
# Out:
# 4.0

# %%
d=a-b
print(d)
# Out:
# (-3+7j)

# %%
e=a*b
print(e)
# Out:
# (22+14j)

# %%
f=a/b
print(f)
# Out:
# (-0.05882352941176469+0.7647058823529412j)

# %%
5.67
# Out:
# 5.67

# %%
type(5.67)
# Out:
# float

# %%
int(5.67)
# Out:
# 5

# %%
x=7.8
type(x)
# Out:
# float

# %%
int(x)
# Out:
# 7

# %%
type(6)
# Out:
# int

# %%
float(6)
# Out:
# 6.0

# %%
complex(6)
# Out:
# (6+0j)

# %%
f=8
g=complex(f)
print(g)
# Out:
# (8+0j)

# %%
type(g)
# Out:
# complex

# %%
int(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1980\3663981408.py in <module>
# ----> 1 int(g)
#
# TypeError: can't convert complex to int

# %%
p="syed"
print(p)
type(p)
# Out:
# syed
# str

# %%
int(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1980\500031207.py in <module>
# ----> 1 int(p)
#
# ValueError: invalid literal for int() with base 10: 'syed'

# %%
float(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1980\4032858928.py in <module>
# ----> 1 float(p)
#
# ValueError: could not convert string to float: 'syed'

# %%
k=9.8
type(k)
# Out:
# float

# %%
complex(k)
# Out:
# (9.8+0j)

# %%
x=28.7

# %%
int(x)
# Out:
# 28

# %%
round(x)
# Out:
# 29

# %%
x=93.34836

# %%
round(x)
# Out:
# 93

# %%
round(x,2)
# Out:
# 93.35

# %%
round(x,3)
# Out:
# 93.348

# %%
round(x,0)
# Out:
# 93.0

# %%
round(x,1)
# Out:
# 93.3

# %%
type(x)
# Out:
# float

# %%
type(round(x))
# Out:
# int

# %%
type(round(x,0))
# Out:
# float

# %%
x=28793.54836

# %%
round(x)
# Out:
# 28794

# %%
round(x,-1)
# Out:
# 28790.0

# %%
round(x,-2)
# Out:
# 28800.0

# %%
round(x,-3)
# Out:
# 29000.0

# %%
imran=7

# %%
imran_87=9

# %%
@im=6
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_1980\937115549.py", line 1
#     @im=6
#        ^
# SyntaxError: invalid syntax

# %%
_imr=9

# %%
8imr=9
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_1980\1999805192.py", line 1
#     8imr=9
#      ^
# SyntaxError: invalid syntax

# %%
imr8=9

# %%
IMR8=9

# %%
imr uy 5=7
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_1980\1453367352.py", line 1
#     imr uy 5=7
#         ^
# SyntaxError: invalid syntax

# %%
else=8
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_1980\3296975998.py", line 1
#     else=8
#     ^
# SyntaxError: invalid syntax

# %%
print=9

# %%
false=7

# %%
False=9
# Out:
#   File "C:\Users\imran\AppData\Local\Temp\ipykernel_1980\584940881.py", line 1
#     False=9
#     ^
# SyntaxError: cannot assign to False

# %% [markdown]
# # Operators and Operands

# %% [markdown]
# Addition

# %%
5+6
# Out:
# 11

# %% [markdown]
# Subtraction

# %%
9-7
# Out:
# 2

# %% [markdown]
# Multiply

# %%
6*7
# Out:
# 42

# %% [markdown]
# Division

# %%
98/7
# Out:
# 14.0

# %% [markdown]
# modulus

# %%
36%5
# Out:
# 1

# %%
36/5
# Out:
# 7.2

# %%
Exponent

# %%
4**2
# Out:
# 16

# %% [markdown]
# Floor

# %%
36//5
# Out:
# 7

# %%
int(36/5)
# Out:
# 7

# %%
35/5
# Out:
# 7.0

# %%
int(35/5)
# Out:
# 7

# %%
x=56

# %%
y=8

# %%
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x**y)
print(x//y)
# Out:
# 64
# 48
# 448
# 7.0
# 96717311574016
# 7

# %%
x=8
y=7
y+=12

# %%
print(y)
# Out:
# 19

# %%
y=7
y-=3
print(y)
# Out:
# 4

# %%
x=6
y=7
x+=y
print(x)
print(y)
# Out:
# 13
# 7

# %%
x=6
y=7
x-=y
print(x)
print(y)
# Out:
# -1
# 7

# %%
x=6
y=7
x*=y
print(x)
print(y)
# Out:
# 42
# 7

# %%
x=6
x*=2
print(x)
# Out:
# 12

# %%
x=6
x/=2
print(x)
# Out:
# 3.0

# %%
x=62
y=7
x/=y
print(x)
print(y)
# Out:
# 8.857142857142858
# 7

# %%
x=62
y=7
x//=y
print(x)
print(y)
# Out:
# 8
# 7

# %%
x=63
x/=2
print(x)
# Out:
# 31.5

# %%
x=63
x//=2
print(x)
# Out:
# 31
